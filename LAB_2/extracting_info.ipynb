# %% [markdown]
# # Practical 3

# %% [markdown]
# ## AIM : To perform exploratory data analysis (EDA) on a student dataset with the objective of:
# - ### Summarizing demographic attributes (e.g., gender, state, category).
# - ### Identifying financial dues among students.
# - ### Detecting missing information (e.g., Aadhaar numbers).
# - ### Filtering students based on conditions (e.g., specific mentor, dues pending).

# %%
import pandas as pd

# %%
rows,cols = df.shape
print(f"rows = {rows}\ncols = {cols}")
# Out:
# rows = 622
# cols = 26

# %%
df = pd.read_csv('student_list.csv')
df
# Out:
#      S.No. Semester                           Branch /Course  \
# 0      NaN      NaN                                      NaN
# 1      1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2      2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3      3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4      4.0    5CSA1  B.Tech - Computer Science & Engineering
# ..     ...      ...                                      ...
# 617    NaN      NaN                                      NaN
# 618    NaN      NaN                                      NaN
# 619    NaN      NaN                                      NaN
# 620    NaN      NaN                                      NaN
# 621    NaN      NaN                                      NaN
#
#     University Registration No. (Issued by R&S Branch)  \
# 0                                                  NaN
# 1                                          22/FET/0062
# 2                                          22/FET/0063
# ...

# %%
extracted_data = df[['Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN', 'Roll No.', 'mentors']]
extracted_data
# Out:
#     Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 0                                      Name of Student
# 1                                           YASH VERMA
# 2                                    KUMARI JAN NASHIN
# 3                                         MANAS RANJAN
# 4                                SUMIT KUMAR CHAURASIA
# ..                                                 ...
# 617                                                NaN
# 618                                                NaN
# 619                                                NaN
# 620                                                NaN
# 621                                                NaN
#
#              Roll No.                   mentors
# 0                 NaN                       NaN
# 1    1/22/FET/BCS/002           Dr SURESH KUMAR
# 2    1/22/FET/BCS/003        Ms SAMEEKSHA KHARE
# 3    1/22/FET/BCS/004           Dr INDU KASHYAP
# ...

# %%
filtered_data = extracted_data[extracted_data['Roll No.'] == '1/22/FET/BCS/049']
filtered_data
# Out:
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 45                                       NILESH BARAT
#
#             Roll No.         mentors
# 45  1/22/FET/BCS/049  Dr MONIKA SHAH

# %%
filtered_data = filtered_data.rename(columns={
    'Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN': 'NAME'
})
filtered_data
# Out:
#             NAME          Roll No.         mentors
# 45  NILESH BARAT  1/22/FET/BCS/049  Dr MONIKA SHAH

# %%
df
# Out:
#      S.No. Semester                           Branch /Course  \
# 0      NaN      NaN                                      NaN
# 1      1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2      2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3      3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4      4.0    5CSA1  B.Tech - Computer Science & Engineering
# ..     ...      ...                                      ...
# 617    NaN      NaN                                      NaN
# 618    NaN      NaN                                      NaN
# 619    NaN      NaN                                      NaN
# 620    NaN      NaN                                      NaN
# 621    NaN      NaN                                      NaN
#
#     University Registration No. (Issued by R&S Branch)  \
# 0                                                  NaN
# 1                                          22/FET/0062
# 2                                          22/FET/0063
# ...

# %%
df[df['Gender'] == 'MALE']
# Out:
#     S.No. Semester                           Branch /Course  \
# 1     1.0    5CSA1  B.Tech - Computer Science & Engineering
# 3     3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4     4.0    5CSA1  B.Tech - Computer Science & Engineering
# 5     5.0    5CSA1  B.Tech - Computer Science & Engineering
# 6     6.0    5CSA1  B.Tech - Computer Science & Engineering
# 7     7.0    5CSA1  B.Tech - Computer Science & Engineering
# 8     8.0    5CSA1  B.Tech - Computer Science & Engineering
# 10   10.0    5CSA1  B.Tech - Computer Science & Engineering
# 11   11.0    5CSA1  B.Tech - Computer Science & Engineering
# 12   12.0    5CSA1  B.Tech - Computer Science & Engineering
# 13   13.0    5CSA1  B.Tech - Computer Science & Engineering
# 14   14.0    5CSA1  B.Tech - Computer Science & Engineering
# 15   15.0    5CSA1  B.Tech - Computer Science & Engineering
# 16   16.0    5CSA1  B.Tech - Computer Science & Engineering
# 17   17.0    5CSA1  B.Tech - Computer Science & Engineering
# ...

# %%
df[df['Gender'] == 'FEMALE']
# Out:
#     S.No. Semester                           Branch /Course  \
# 2     2.0    5CSA1  B.Tech - Computer Science & Engineering
# 9     9.0    5CSA1  B.Tech - Computer Science & Engineering
# 20   20.0    5CSA1  B.Tech - Computer Science & Engineering
# 22   22.0    5CSA1  B.Tech - Computer Science & Engineering
# 25   25.0    5CSA1  B.Tech - Computer Science & Engineering
# 26   26.0    5CSA1  B.Tech - Computer Science & Engineering
# 30   30.0    5CSA2  B.Tech - Computer Science & Engineering
# 34   34.0    5CSA2  B.Tech - Computer Science & Engineering
# 35   35.0    5CSA2  B.Tech - Computer Science & Engineering
# 38   38.0    5CSA2  B.Tech - Computer Science & Engineering
# 47   47.0    5CSA2  B.Tech - Computer Science & Engineering
# 54   54.0    5CSA2  B.Tech - Computer Science & Engineering
# 61   61.0    5CSA1  B.Tech - Computer Science & Engineering
#
#    University Registration No. (Issued by R&S Branch)  \
# 2                                         22/FET/0063
# ...

# %%
df
# Out:
#      S.No. Semester                           Branch /Course  \
# 0      NaN      NaN                                      NaN
# 1      1.0    5CSA1  B.Tech - Computer Science & Engineering
# 2      2.0    5CSA1  B.Tech - Computer Science & Engineering
# 3      3.0    5CSA1  B.Tech - Computer Science & Engineering
# 4      4.0    5CSA1  B.Tech - Computer Science & Engineering
# ..     ...      ...                                      ...
# 617    NaN      NaN                                      NaN
# 618    NaN      NaN                                      NaN
# 619    NaN      NaN                                      NaN
# 620    NaN      NaN                                      NaN
# 621    NaN      NaN                                      NaN
#
#     University Registration No. (Issued by R&S Branch)  \
# 0                                                  NaN
# 1                                          22/FET/0062
# 2                                          22/FET/0063
# ...

# %%
grouped = df.groupby('Category')

# %%
for category ,group in grouped:
    print(f"Catagory : {category}")
    print(group[['Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN']])
# Out:
# Catagory : GENERAL
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN
# 2                                   KUMARI JAN NASHIN
# 4                               SUMIT KUMAR CHAURASIA
# 6                                          ATUL KUMAR
# 7                                            ABHISHEK
# 8                                     ANIRUDDH SHARMA
# 10                                 SIDDHARTH BHARDWAJ
# 11                                       KRISHNA NEGI
# 12                                      AKASH MALLICK
# 13                           KRISHAN KANT KANT SHARMA
# 14                                      MAYANK TANWAR
# 15                                        HARSH SINGH
# 16                                       TUSHAR RAWAT
# 17                                      SOURAV RAJPUT
# 18                                 MUGDH KUMAR SHARMA
# 19                                    SHASHANK PANDEY
# ...

# %%
state = df[df['State']=='DELHI']
state
# Out:
#     S.No. Semester                           Branch /Course  \
# 4     4.0    5CSA1  B.Tech - Computer Science & Engineering
# 9     9.0    5CSA1  B.Tech - Computer Science & Engineering
# 13   13.0    5CSA1  B.Tech - Computer Science & Engineering
# 21   21.0    5CSA1  B.Tech - Computer Science & Engineering
# 26   26.0    5CSA1  B.Tech - Computer Science & Engineering
# 28   28.0    5CSA1  B.Tech - Computer Science & Engineering
# 29   29.0    5CSA2  B.Tech - Computer Science & Engineering
# 30   30.0    5CSA2  B.Tech - Computer Science & Engineering
# 33   33.0    5CSA2  B.Tech - Computer Science & Engineering
# 46   46.0    5CSA2  B.Tech - Computer Science & Engineering
# 50   50.0    5CSA2  B.Tech - Computer Science & Engineering
# 59   59.0    5CSA2  B.Tech - Computer Science & Engineering
#
#    University Registration No. (Issued by R&S Branch)  \
# 4                                         22/FET/0065
# 9                                         22/FET/0519
# ...

# %%
mentee = df[df['mentors'] == 'Dr POONAM NANDAL']
mentee
# Out:
#    S.No. Semester                           Branch /Course  \
# 5    5.0    5CSA1  B.Tech - Computer Science & Engineering
# 6    6.0    5CSA1  B.Tech - Computer Science & Engineering
#
#   University Registration No. (Issued by R&S Branch)  \
# 5                                        22/FET/0066
# 6                                        22/FET/0067
#
#   Date of Admission in the Present Class/Course          Roll No.  \
# 5                                    29.07.2024  1/22/FET/BCS/006
# 6                                    29.07.2024  1/22/FET/BCS/007
#
#   Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 5                                       SHIVAM SINGH
# 6                                         ATUL KUMAR
#
#   Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN  \
# 5                                         GYAN SINGH
# 6                                       RAVINDRA RAI
#
# ...

# %%
null_aadhaar = df[df['Aadhaar No. of Student'] == '0'] 
null_aadhaar
# Out:
#     S.No. Semester                           Branch /Course  \
# 16   16.0    5CSA1  B.Tech - Computer Science & Engineering
# 38   38.0    5CSA2  B.Tech - Computer Science & Engineering
#
#    University Registration No. (Issued by R&S Branch)  \
# 16                                        22/FET/0076
# 38                                        22/FET/0097
#
#    Date of Admission in the Present Class/Course          Roll No.  \
# 16                                    29.07.2024  1/22/FET/BCS/018
# 38                                    29.07.2024  1/22/FET/BCS/042
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 16                                       TUSHAR RAWAT
# 38                                         ANISHA SAH
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-FN  \
# 16                              INDERJEET SINGH RAWAT
# 38                                  UMESH PRASAD KANU
#
# ...

# %%
total_pending = df[df['Total Due Fee for Current Semester / (Previous semester if pending)'].notnull()]['Total Due Fee for Current Semester / (Previous semester if pending)'].sum()
total_pending
# Out:
# np.float64(477520.0)

# %%
pending = df[(df['Total Due Fee for Current Semester / (Previous semester if pending)'].notnull()) & 
              (df['Total Due Fee for Current Semester / (Previous semester if pending)'] != 0.0)]
pending
# Out:
#     S.No. Semester                           Branch /Course  \
# 15   15.0    5CSA1  B.Tech - Computer Science & Engineering
# 24   24.0    5CSA1  B.Tech - Computer Science & Engineering
# 39   39.0    5CSA2  B.Tech - Computer Science & Engineering
#
#    University Registration No. (Issued by R&S Branch)  \
# 15                                        22/FET/0075
# 24                                        22/FET/0084
# 39                                        22/FET/0098
#
#    Date of Admission in the Present Class/Course          Roll No.  \
# 15                                    29.07.2024  1/22/FET/BCS/017
# 24                                    29.07.2024  1/22/FET/BCS/027
# 39                                    29.07.2024  1/22/FET/BCS/043
#
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN  \
# 15                                        HARSH SINGH
# 24                                     ASHUTOSH KUMAR
# ...

# %%
state_groupe = df.groupby('State')

# %%
for state ,group in state_groupe:
    print(f"state : {state}")
    print(group[['Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN']])
# Out:
# state : 0
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN
# 25                                     ARUNIMA SHARMA
# state : BIHAR
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN
# 3                                        MANAS RANJAN
# 6                                          ATUL KUMAR
# 15                                        HARSH SINGH
# 24                                     ASHUTOSH KUMAR
# 36                                        RAHUL KUMAR
# 39                                         PIYUSH RAJ
# state : DELHI
#    Spelling strictly as per Registration record in Capital Letters (Issued by R&S Branch)-SN
# 4                               SUMIT KUMAR CHAURASIA
# 9                                  N. JACINTHA JANICE
# 13                           KRISHAN KANT KANT SHARMA
# 21                               MAHENDRA SINGH RAWAT
# ...

# %%
rows ,cols = df.shape
print(f"rows:{rows}\ncols:{cols}")
# Out:
# rows:622
# cols:26
